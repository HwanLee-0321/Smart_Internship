# %% [markdown]
# ### Object Detection (객체 탐지)
# 1. 분류(Classification): 물체가 어떤 물체인지 클래스를 구분하는 문제
# 2. Localization: 물체가 어디에 있는지 바운딩박스 위치 정보를 나타내는 문제
# 3. Object Detection: Classification + Localization 을 동시에 진행하는 것

# %% [markdown]
# ### YOLO ( You Only Look Once)
# - https://docs.ultralytics.com/

# %% [markdown]
# | 연도         | 버전       | 주요 개선 사항 및 특징                                                                                                                                                                                                      |
# |--------------|------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | 2016         | YOLO (v1)  | - 워싱턴 대학교 조셉 레드몬, 알리 파르하디가 개발<br>- 단일 단계(single-stage) 객체 탐지 기법 도입<br>- 이미지를 S×S 격자로 나누어 위치+클래스를 동시에 예측<br>- 7×7 그리드, 각 셀에서 2개의 바운딩 박스와 클래스 확률 출력 |
# | 2017         | YOLOv2     | - “YOLO9000: Better, Faster, Stronger” 논문<br>- 앵커 박스 개념 도입(Faster R-CNN에서 차용)<br>- 차원 클러스터링(Anchor Box 크기 최적화)<br>- 다중 스케일(multiscale) 학습과 일괄 정규화(BN) 적용                                 |
# | 2018         | YOLOv3     | - Darknet-53 백본 사용(잔차 블록+스킵 커넥션 구조)<br>- 3단계(3-scale) 예측으로 작은 물체 인식 성능 개선<br>- 시그모이드 함수를 통한 바운딩 박스 좌표 예측<br>- 공간 피라미드 풀링(SPP) 아이디어 일부 반영                          |
# | 2020년 4월   | YOLOv4     | - CSPDarknet53 백본 도입 및 Mosaic 데이터 증강<br>- BoF(Freebies), BoS(Specials) 기법 등 다양한 최적화 기법 집약<br>- SPP 추가, Weighted-Residual-Connection(WRC) 적용<br>- 빠른 추론 속도와 높은 정확도 달성                |
# | 2020년 6월   | YOLOv5     | - Ultralytics에서 PyTorch 기반으로 개발<br>- 자동 앵커(Auto Anchor), 모자이크 증강 등 다양한 편의 기능<br>- 하이퍼파라미터 최적화 및 통합 실험 추적 제공<br>- 모델 크기가 작아지고, v4 대비 약 10% 이상 성능 향상                     |
# | 2022년 7월   | YOLOv7     | - 기존 YOLO 계열 대비 학습 과정 최적화 및 연산량 감소<br>- E-ELAN(Extended ELAN) 구조를 활용하여 성능 강화<br>- trainable bag of freebies 등 학습 전략 다수 제안<br>- 실시간 객체 탐지 분야에서 높은 정확도 및 속도 제공         |
# | 2022년 9월   | YOLOv6     | - Meituan(메이투안)에서 개발<br>- 앵커 기반 + 앵커 프리 방식 모두 지원<br>- Quantization, Knowledge Distillation 기법 도입<br>- 효율적 구조 재설계를 통해 속도·정확도 동시 개선                                           |
# | 2023년 1월   | YOLOv8     | - Ultralytics에서 새롭게 공개한 통합 프레임워크<br>- 앵커 프리(Anchor-free) 기법 및 디커플 헤드(Decoupled Head) 적용<br>- 객체 감지, 인스턴스 세분화 등 다양한 시각지능 모델링에 사용<br>- 이전 버전 대비 가볍고 정확도 개선         |
# | 2024년 2월   | YOLOv9     | - 기존 네트워크에서 정보 손실 문제를 해결하기 위해 PGI(Preserved Gradient Integration) 적용<br>- GELAN(Generalized ELAN) 신경망 구조로 업그레이드<br>- 연산 효율과 정확도를 동시에 향상                                           |
# | 2024년 5월   | YOLOv10    | - 칭화대 연구진이 Ultralytics Python 패키지를 활용해 개발<br>- 비최대 억제(NMS) 제거한 엔드투엔드 감지 헤드 도입<br>- 고난도 환경에서의 물체 분할 및 인식 정확도 개선                                                               |
# | 2024년 9월   | YOLOv11    | - 물체 감지, 세분화, 포즈 추정, 추적, 분류 등 다양한 작업에서 최첨단(SOTA) 성능 제공<br>- Ultralytics YOLO 계열의 최신 버전<br>- 확장된 멀티태스킹 능력으로 산업·연구 분야에서 활용도 증대                                              |
#
# - **주요 개선사항 요약**
#   - **YOLO ~ YOLOv3**: 격자 기반 단일 단계 예측 구조를 유지하면서 앵커 박스, 멀티 스케일 예측 등 주요 기능 추가
#   - **YOLOv4 ~ YOLOv7**: 백본 네트워크 개선(CSPDarknet53, E-ELAN 등), 다양한 데이터 증강(Mosaic 등) 및 학습 최적화 기법 도입
#   - **YOLOv8 ~**: 앵커 프리, 디커플 헤드, 엔드투엔드 감지 헤드 등 새로운 접근으로 정확도·속도 동시 향상
#
# > - `Latency T4 TensorRT10 FP16` : Nvidia T4 GPU에서 TensorRT 10 최적화와 FP16 연산 방식을 사용하여, 모델이 얼마나 빠르게 예측을 수행하는지를 측정한 값
# > - `COCO mAP` : COCO 데이터셋을 기준으로, 모델이 객체를 얼마나 정확하게 감지하는지를 평가하는 대표적인 성능 지표

# %% [markdown]
# ### 학습목표
# - 음식 사진을 보고 종류를 분류하는 모델을 만들어보자!

# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# %cd /content/drive/MyDrive/딥러닝
# Out:
# /content/drive/MyDrive/딥러닝

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/딥러닝'

# %%
# !unzip ./data/food.zip -d ./data/food/

# %% [markdown]
# ### YOLO 폴더 구조 준비
# - YOLO 모델은 각 task(작업단위)별로 요구하는 폴더구조가 상이!
# - 폴더 구조 가이드라인에 맞추어 구성해야 학습이 가능

# %%
import os  # 파일/디렉토리 등 os 관련 명령어들 수행

# %%
# 각 이미지 파일명을 변수로 지정
apple_pie_filenames = os.listdir("./data/food/apple_pie")
donuts_filenames = os.listdir("./data/food/donuts")
hamburger_filenames = os.listdir("./data/food/hamburger")
onion_rings_filenames = os.listdir("./data/food/onion_rings")
pizza_filenames = os.listdir("./data/food/pizza")

# %%
len(apple_pie_filenames),len(donuts_filenames), len(hamburger_filenames), len(onion_rings_filenames), len(pizza_filenames)
# Out:
# (1000, 1000, 1000, 1000, 1000)

# %%
# 폴더 생성
if not os.path.exists("./data/food_for_yolo"):  # 폴더의 존재여부 확인
    os.mkdir("./data/food_for_yolo")  # 디텍토리 생성

# train, test, val폴더 생성
if not os.path.exists("./data/food_for_yolo/train"):  # 폴더의 존재여부 확인
    os.mkdir("./data/food_for_yolo/train")  # 디텍토리 생성

if not os.path.exists("./data/food_for_yolo/test"):  # 폴더의 존재여부 확인
    os.mkdir("./data/food_for_yolo/test")  # 디텍토리 생성

if not os.path.exists("./data/food_for_yolo/val"):  # 폴더의 존재여부 확인
    os.mkdir("./data/food_for_yolo/val")  # 디텍토리 생성

# %%
# 하위 폴더 생성하기
food_list = ["apple_pie", "donuts", "hamburger", "onion_rings", "pizza"]
folder_list = ["./data/food_for_yolo/train", "./data/food_for_yolo/test", "./data/food_for_yolo/val"]

for folder_path in folder_list:
    for food in food_list:
        if not os.path.exists(folder_path + "/" + food):
            os.mkdir(folder_path + "/" + food)

# %% [markdown]
# - 훈련용: 640장
# - 검증용: 200장
# - 평가용: 160장

# %%
import shutil  # 파일 모음에 대한 고수준 연산을 제공

# train set 사진 이동
for img_name in apple_pie_filenames[:640]:
    shutil.move("./data/food/apple_pie/" + img_name,
                "./data/food_for_yolo/train/apple_pie/" + img_name)
# val set 사진 이동
for img_name in apple_pie_filenames[640:801]:
    shutil.move("./data/food/apple_pie/" + img_name,
                "./data/food_for_yolo/val/apple_pie/" + img_name)
# test set 사진 이동
for img_name in apple_pie_filenames[801:]:
    shutil.move("./data/food/apple_pie/" + img_name,
                "./data/food_for_yolo/test/apple_pie/" + img_name)

# %%
from tqdm.auto import tqdm  # 반복문 진행현황 출력도구

# %%
# 나머지 클래스들도
food_filenames =[donuts_filenames, hamburger_filenames, onion_rings_filenames, pizza_filenames]

for food, img_list in zip(food_list[1:], food_filenames):
    for img_name in img_list[:640]:
        shutil.move("./data/food/"+ food + '/' + img_name,
                    "./data/food_for_yolo/train/"+ food + '/' + img_name)
    for img_name in img_list[640:801]:
        shutil.move("./data/food/"+ food + '/' + img_name,
                    "./data/food_for_yolo/val/"+ food + '/' + img_name)
    for img_name in img_list[801:]:
        shutil.move("./data/food/"+ food + '/' + img_name,
                    "./data/food_for_yolo/test/"+ food + '/' + img_name)

# %%
# 각 이미지 파일명을 변수로 지정
apple_pie_filenames = os.listdir("./data/food/apple_pie")
donuts_filenames = os.listdir("./data/food/donuts")
hamburger_filenames = os.listdir("./data/food/hamburger")
onion_rings_filenames = os.listdir("./data/food/onion_rings")
pizza_filenames = os.listdir("./data/food/pizza")

# %%
len(apple_pie_filenames),len(donuts_filenames), len(hamburger_filenames), len(onion_rings_filenames), len(pizza_filenames)
# Out:
# (0, 0, 0, 0, 0)

# %% [markdown]
# ### YOLO학습하기 v11

# %%
# !pip -q install ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.2 MB/s eta 0:00:00

# %%
from ultralytics import YOLO  #울트라리틱스에서 제공하고 있는 모델, 또는 학습이 완료된 모델 등을 다룰 수 있는 도구
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# 미리 학습되어 있는 모델 가중치 파일 이용해서 YOLO cls 모델 생성
model = YOLO("./data/yolo11n-cls.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-cls.pt to 'data/yolo11n-cls.pt'...
# 100%|██████████| 5.52M/5.52M [00:00<00:00, 95.9MB/s]

# %%
# 학습
results = model.train(data="./data/food_for_yolo/", epochs=20, imgsz = 224)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=./data/food_for_yolo/, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=./data/yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/classify/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /content/drive/MyDrive/딥러닝/data/food_for_yolo/train... found 3200 images in 5 classes ✅
# val: /content/drive/MyDrive/딥러닝/data/food_for_yolo/val... found 805 images in 5 classes ✅
# test: /content/drive/MyDrive/딥러닝/data/food_for_yolo/test... found 995 images in 5 classes ✅
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    336645  ultralytics.nn.modules.head.Classify         [256, 5]
# YOLO11n-cls summary: 86 layers, 1,537,509 parameters, 1,537,509 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 87.5MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.0 ms, read: 11.0±4.7 MB/s, size: 43.1 KB)
# train: Scanning /content/drive/MyDrive/딥러닝/data/food_for_yolo/train... 3200 images, 0 corrupt: 100%|██████████| 3200/3200 [00:17<00:00, 185.88it/s]
# train: New cache created: /content/drive/MyDrive/딥러닝/data/food_for_yolo/train.cache
# val: Fast image access ✅ (ping: 2.7±4.1 ms, read: 4.6±3.3 MB/s, size: 41.3 KB)
# val: Scanning /content/drive/MyDrive/딥러닝/data/food_for_yolo/val... 805 images, 0 corrupt: 100%|██████████| 805/805 [00:04<00:00, 167.91it/s]
# val: New cache created: /content/drive/MyDrive/딥러닝/data/food_for_yolo/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to runs/classify/train
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/20     0.275G      1.677         16        224:   3%|▎         | 6/200 [00:01<00:34,  5.66it/s]
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
#        1/20     0.275G       1.67         16        224:   6%|▌         | 11/200 [00:02<00:32,  5.84it/s]
# 100%|██████████| 755k/755k [00:00<00:00, 20.4MB/s]
#        1/20     0.279G     0.9462         16        224: 100%|██████████| 200/200 [00:40<00:00,  4.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:05<00:00,  4.41it/s]
#                    all      0.881          1
#       Epoch    GPU_mem       loss  Instances       Size
#        2/20     0.287G     0.5749         16        224: 100%|██████████| 200/200 [00:38<00:00,  5.20it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:05<00:00,  4.55it/s]
#                    all      0.858          1
#       Epoch    GPU_mem       loss  Instances       Size
#        3/20     0.297G     0.5135         16        224: 100%|██████████| 200/200 [00:38<00:00,  5.15it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:06<00:00,  3.88it/s]
#                    all      0.886          1
#       Epoch    GPU_mem       loss  Instances       Size
#        4/20     0.305G     0.5083         16        224: 100%|██████████| 200/200 [00:37<00:00,  5.33it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:07<00:00,  3.62it/s]
#                    all      0.842          1
#       Epoch    GPU_mem       loss  Instances       Size
#        5/20     0.314G     0.4669         16        224: 100%|██████████| 200/200 [00:38<00:00,  5.18it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:05<00:00,  4.72it/s]
#                    all      0.852          1
#       Epoch    GPU_mem       loss  Instances       Size
#        6/20     0.322G     0.4397         16        224: 100%|██████████| 200/200 [00:38<00:00,  5.24it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:05<00:00,  4.82it/s]
#                    all      0.916          1
#       Epoch    GPU_mem       loss  Instances       Size
#        7/20      0.33G     0.3777         16        224: 100%|██████████| 200/200 [00:37<00:00,  5.27it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:06<00:00,  3.84it/s]
#                    all      0.894          1
#       Epoch    GPU_mem       loss  Instances       Size
#        8/20      0.34G     0.3638         16        224: 100%|██████████| 200/200 [00:36<00:00,  5.49it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:07<00:00,  3.63it/s]
#                    all      0.897          1
#       Epoch    GPU_mem       loss  Instances       Size
#        9/20     0.348G     0.3296         16        224: 100%|██████████| 200/200 [00:39<00:00,  5.11it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:05<00:00,  4.77it/s]
#                    all      0.912          1
#       Epoch    GPU_mem       loss  Instances       Size
#       10/20     0.357G      0.274         16        224: 100%|██████████| 200/200 [00:38<00:00,  5.17it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:05<00:00,  4.60it/s]
#                    all      0.913          1
#       Epoch    GPU_mem       loss  Instances       Size
#       11/20     0.365G     0.2478         16        224: 100%|██████████| 200/200 [00:40<00:00,  4.98it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:07<00:00,  3.67it/s]
#                    all      0.924          1
#       Epoch    GPU_mem       loss  Instances       Size
#       12/20     0.375G     0.2193         16        224: 100%|██████████| 200/200 [00:39<00:00,  5.01it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:06<00:00,  4.31it/s]
#                    all      0.916          1
#       Epoch    GPU_mem       loss  Instances       Size
#       13/20     0.383G     0.2174         16        224: 100%|██████████| 200/200 [00:38<00:00,  5.13it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:06<00:00,  3.77it/s]
#                    all      0.927          1
#       Epoch    GPU_mem       loss  Instances       Size
#       14/20     0.393G       0.19         16        224: 100%|██████████| 200/200 [00:38<00:00,  5.26it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:07<00:00,  3.62it/s]
#                    all       0.93          1
#       Epoch    GPU_mem       loss  Instances       Size
#       15/20       0.4G     0.1653         16        224: 100%|██████████| 200/200 [00:40<00:00,  4.95it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:05<00:00,  4.53it/s]
#                    all      0.935          1
#       Epoch    GPU_mem       loss  Instances       Size
#       16/20      0.41G     0.1254         16        224: 100%|██████████| 200/200 [00:40<00:00,  4.94it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:07<00:00,  3.65it/s]
#                    all      0.937          1
#       Epoch    GPU_mem       loss  Instances       Size
#       17/20     0.418G     0.1305         16        224: 100%|██████████| 200/200 [00:39<00:00,  5.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:06<00:00,  4.23it/s]
#                    all      0.935          1
#       Epoch    GPU_mem       loss  Instances       Size
#       18/20     0.428G     0.1105         16        224: 100%|██████████| 200/200 [00:41<00:00,  4.87it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:05<00:00,  4.49it/s]
#                    all      0.937          1
#       Epoch    GPU_mem       loss  Instances       Size
#       19/20     0.436G     0.1098         16        224: 100%|██████████| 200/200 [00:40<00:00,  4.97it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:07<00:00,  3.59it/s]
#                    all      0.939          1
#       Epoch    GPU_mem       loss  Instances       Size
#       20/20     0.445G    0.09104         16        224: 100%|██████████| 200/200 [00:41<00:00,  4.83it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:05<00:00,  4.51it/s]
#                    all      0.935          1
# 20 epochs completed in 0.256 hours.
# Optimizer stripped from runs/classify/train/weights/last.pt, 3.2MB
# Optimizer stripped from runs/classify/train/weights/best.pt, 3.2MB
#
# Validating runs/classify/train/weights/best.pt...
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,532,429 parameters, 0 gradients, 3.2 GFLOPs
# train: /content/drive/MyDrive/딥러닝/data/food_for_yolo/train... found 3200 images in 5 classes ✅
# val: /content/drive/MyDrive/딥러닝/data/food_for_yolo/val... found 805 images in 5 classes ✅
# test: /content/drive/MyDrive/딥러닝/data/food_for_yolo/test... found 995 images in 5 classes ✅
#                classes   top1_acc   top5_acc: 100%|██████████| 26/26 [00:07<00:00,  3.55it/s]
#                    all      0.939          1
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train

# %%
# 학습이 끝난 모델 로드
loaded_model = YOLO("./runs/classify/train/weights/best.pt")

# %%
# 예측
results = loaded_model("./data/food_for_yolo/test/apple_pie/")
# Out:
# image 1/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1014775.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, pizza 0.00, hamburger 0.00, donuts 0.00, 29.2ms
# image 2/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/110043.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, donuts 0.00, pizza 0.00, hamburger 0.00, 9.6ms
# image 3/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1106961.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, donuts 0.00, 7.1ms
# image 4/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1112838.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, pizza 0.00, 9.5ms
# image 5/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/112378.jpg: 224x224 apple_pie 0.72, onion_rings 0.15, donuts 0.11, pizza 0.01, hamburger 0.00, 7.6ms
# image 6/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1165004.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 6.2ms
# image 7/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1185654.jpg: 224x224 apple_pie 0.99, donuts 0.01, pizza 0.00, hamburger 0.00, onion_rings 0.00, 5.8ms
# image 8/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1196628.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, pizza 0.00, donuts 0.00, hamburger 0.00, 5.9ms
# image 9/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1199851.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, pizza 0.00, onion_rings 0.00, 6.1ms
# image 10/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/123782.jpg: 224x224 apple_pie 0.88, onion_rings 0.11, pizza 0.01, donuts 0.00, hamburger 0.00, 6.0ms
# image 11/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1265307.jpg: 224x224 donuts 0.40, apple_pie 0.32, hamburger 0.28, onion_rings 0.00, pizza 0.00, 5.7ms
# image 12/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/128259.jpg: 224x224 apple_pie 0.91, pizza 0.09, onion_rings 0.00, hamburger 0.00, donuts 0.00, 5.8ms
# image 13/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1284428.jpg: 224x224 onion_rings 0.83, apple_pie 0.13, hamburger 0.04, pizza 0.00, donuts 0.00, 5.8ms
# image 14/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/134.jpg: 224x224 apple_pie 0.99, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 5.6ms
# image 15/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1348788.jpg: 224x224 apple_pie 0.96, onion_rings 0.03, donuts 0.00, pizza 0.00, hamburger 0.00, 5.6ms
# image 16/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1375404.jpg: 224x224 apple_pie 1.00, donuts 0.00, onion_rings 0.00, hamburger 0.00, pizza 0.00, 6.0ms
# image 17/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1376013.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 6.4ms
# image 18/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1398774.jpg: 224x224 donuts 0.97, apple_pie 0.02, onion_rings 0.01, hamburger 0.00, pizza 0.00, 5.5ms
# image 19/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1420227.jpg: 224x224 donuts 0.77, apple_pie 0.19, onion_rings 0.03, hamburger 0.00, pizza 0.00, 5.4ms
# image 20/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/142332.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, pizza 0.00, onion_rings 0.00, 5.4ms
# image 21/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1428585.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 5.3ms
# image 22/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1442421.jpg: 224x224 apple_pie 0.98, hamburger 0.02, donuts 0.00, onion_rings 0.00, pizza 0.00, 5.4ms
# image 23/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1448488.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, pizza 0.00, onion_rings 0.00, 5.8ms
# image 24/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1456028.jpg: 224x224 apple_pie 1.00, donuts 0.00, onion_rings 0.00, hamburger 0.00, pizza 0.00, 6.5ms
# image 25/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1466791.jpg: 224x224 apple_pie 1.00, donuts 0.00, onion_rings 0.00, hamburger 0.00, pizza 0.00, 6.8ms
# image 26/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1472631.jpg: 224x224 apple_pie 0.90, onion_rings 0.10, pizza 0.00, hamburger 0.00, donuts 0.00, 8.6ms
# image 27/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1481550.jpg: 224x224 apple_pie 0.99, hamburger 0.01, donuts 0.00, pizza 0.00, onion_rings 0.00, 5.8ms
# image 28/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1487150.jpg: 224x224 apple_pie 0.89, donuts 0.09, onion_rings 0.03, pizza 0.00, hamburger 0.00, 10.1ms
# image 29/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1510125.jpg: 224x224 apple_pie 0.92, donuts 0.07, hamburger 0.01, onion_rings 0.00, pizza 0.00, 6.3ms
# image 30/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1547651.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, 6.4ms
# image 31/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/156078.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 5.3ms
# image 32/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1596752.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 5.3ms
# image 33/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1620714.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, donuts 0.00, 6.2ms
# image 34/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1648647.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, 5.3ms
# image 35/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1667135.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 7.0ms
# image 36/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1725747.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, onion_rings 0.00, hamburger 0.00, 7.1ms
# image 37/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1727085.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 10.9ms
# image 38/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1739519.jpg: 224x224 apple_pie 0.97, donuts 0.03, onion_rings 0.00, pizza 0.00, hamburger 0.00, 8.6ms
# image 39/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1753171.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, pizza 0.00, donuts 0.00, 7.8ms
# image 40/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1773419.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, pizza 0.00, onion_rings 0.00, 7.8ms
# image 41/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1810149.jpg: 224x224 apple_pie 1.00, pizza 0.00, onion_rings 0.00, donuts 0.00, hamburger 0.00, 7.9ms
# image 42/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1815972.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, donuts 0.00, 7.6ms
# image 43/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1820074.jpg: 224x224 donuts 0.88, apple_pie 0.12, hamburger 0.00, onion_rings 0.00, pizza 0.00, 8.4ms
# image 44/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1830215.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, pizza 0.00, onion_rings 0.00, 5.6ms
# image 45/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1854241.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, pizza 0.00, donuts 0.00, 5.7ms
# image 46/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1919827.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, pizza 0.00, 7.7ms
# image 47/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1954841.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 6.2ms
# image 48/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1963597.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, onion_rings 0.00, hamburger 0.00, 5.3ms
# image 49/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1969851.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 5.4ms
# image 50/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2008772.jpg: 224x224 hamburger 0.98, apple_pie 0.02, pizza 0.00, donuts 0.00, onion_rings 0.00, 6.2ms
# image 51/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2012973.jpg: 224x224 apple_pie 1.00, donuts 0.00, pizza 0.00, hamburger 0.00, onion_rings 0.00, 7.8ms
# image 52/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2074694.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 7.5ms
# image 53/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/21063.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, pizza 0.00, onion_rings 0.00, 9.4ms
# image 54/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2110106.jpg: 224x224 donuts 0.46, apple_pie 0.35, pizza 0.17, hamburger 0.01, onion_rings 0.00, 9.6ms
# image 55/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2114765.jpg: 224x224 donuts 1.00, apple_pie 0.00, onion_rings 0.00, hamburger 0.00, pizza 0.00, 12.5ms
# image 56/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2175701.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 7.7ms
# image 57/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2178254.jpg: 224x224 apple_pie 1.00, donuts 0.00, onion_rings 0.00, pizza 0.00, hamburger 0.00, 6.5ms
# image 58/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2195793.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, pizza 0.00, 7.7ms
# image 59/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2205061.jpg: 224x224 apple_pie 1.00, donuts 0.00, onion_rings 0.00, pizza 0.00, hamburger 0.00, 7.8ms
# image 60/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2254489.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 5.4ms
# image 61/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2306493.jpg: 224x224 apple_pie 0.99, pizza 0.01, onion_rings 0.00, hamburger 0.00, donuts 0.00, 21.3ms
# image 62/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2337097.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, 8.7ms
# image 63/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2337652.jpg: 224x224 pizza 0.88, apple_pie 0.12, hamburger 0.00, onion_rings 0.00, donuts 0.00, 8.1ms
# image 64/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2339010.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, 7.8ms
# image 65/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2345199.jpg: 224x224 apple_pie 1.00, donuts 0.00, pizza 0.00, hamburger 0.00, onion_rings 0.00, 8.0ms
# image 66/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2347111.jpg: 224x224 pizza 0.78, hamburger 0.19, donuts 0.03, apple_pie 0.00, onion_rings 0.00, 7.5ms
# image 67/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/236966.jpg: 224x224 apple_pie 0.98, donuts 0.02, hamburger 0.00, pizza 0.00, onion_rings 0.00, 7.4ms
# image 68/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2400434.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, pizza 0.00, onion_rings 0.00, 7.4ms
# image 69/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2421227.jpg: 224x224 apple_pie 0.99, hamburger 0.01, donuts 0.00, onion_rings 0.00, pizza 0.00, 7.4ms
# image 70/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2446500.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, donuts 0.00, pizza 0.00, hamburger 0.00, 7.8ms
# image 71/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2447106.jpg: 224x224 apple_pie 0.92, donuts 0.06, hamburger 0.02, onion_rings 0.00, pizza 0.00, 7.9ms
# image 72/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2453243.jpg: 224x224 apple_pie 0.61, donuts 0.39, hamburger 0.00, onion_rings 0.00, pizza 0.00, 9.1ms
# image 73/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/245712.jpg: 224x224 apple_pie 0.59, donuts 0.40, hamburger 0.01, onion_rings 0.00, pizza 0.00, 7.5ms
# image 74/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2486622.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, onion_rings 0.00, hamburger 0.00, 8.4ms
# image 75/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2490410.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 8.5ms
# image 76/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2510497.jpg: 224x224 apple_pie 0.69, hamburger 0.20, donuts 0.06, pizza 0.05, onion_rings 0.00, 7.4ms
# image 77/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2519446.jpg: 224x224 apple_pie 0.89, pizza 0.08, donuts 0.02, hamburger 0.01, onion_rings 0.00, 7.6ms
# image 78/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2548878.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, onion_rings 0.00, hamburger 0.00, 8.8ms
# image 79/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2564881.jpg: 224x224 apple_pie 0.59, hamburger 0.22, pizza 0.18, donuts 0.01, onion_rings 0.00, 7.5ms
# image 80/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/257377.jpg: 224x224 apple_pie 0.95, pizza 0.02, donuts 0.02, hamburger 0.01, onion_rings 0.00, 9.0ms
# image 81/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2574026.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, pizza 0.00, 7.7ms
# image 82/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2576737.jpg: 224x224 apple_pie 1.00, pizza 0.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, 7.1ms
# image 83/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2586267.jpg: 224x224 apple_pie 0.98, pizza 0.02, onion_rings 0.00, donuts 0.00, hamburger 0.00, 8.0ms
# image 84/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2591737.jpg: 224x224 apple_pie 0.95, donuts 0.05, hamburger 0.00, onion_rings 0.00, pizza 0.00, 8.0ms
# image 85/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2601847.jpg: 224x224 apple_pie 1.00, pizza 0.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, 8.2ms
# image 86/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2603533.jpg: 224x224 apple_pie 0.91, hamburger 0.09, onion_rings 0.00, donuts 0.00, pizza 0.00, 8.3ms
# image 87/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2605751.jpg: 224x224 apple_pie 0.63, pizza 0.34, donuts 0.01, onion_rings 0.01, hamburger 0.00, 9.5ms
# image 88/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2606415.jpg: 224x224 apple_pie 0.99, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 13.9ms
# image 89/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2607306.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, donuts 0.00, 9.4ms
# image 90/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2626973.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, donuts 0.00, hamburger 0.00, pizza 0.00, 11.9ms
# image 91/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2663191.jpg: 224x224 apple_pie 0.99, hamburger 0.01, donuts 0.00, onion_rings 0.00, pizza 0.00, 10.0ms
# image 92/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2666921.jpg: 224x224 apple_pie 0.82, onion_rings 0.10, donuts 0.07, pizza 0.00, hamburger 0.00, 7.9ms
# image 93/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2708417.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, donuts 0.00, 8.1ms
# image 94/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2721937.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, pizza 0.00, onion_rings 0.00, 8.5ms
# image 95/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2754101.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, donuts 0.00, 7.5ms
# image 96/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2766017.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, onion_rings 0.00, hamburger 0.00, 7.5ms
# image 97/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2777273.jpg: 224x224 onion_rings 0.99, apple_pie 0.01, hamburger 0.00, pizza 0.00, donuts 0.00, 8.4ms
# image 98/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2800543.jpg: 224x224 apple_pie 0.98, pizza 0.01, hamburger 0.00, donuts 0.00, onion_rings 0.00, 7.5ms
# image 99/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/280199.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, pizza 0.00, 7.4ms
# image 100/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2819375.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, pizza 0.00, donuts 0.00, 7.9ms
# image 101/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2819833.jpg: 224x224 apple_pie 0.68, hamburger 0.30, pizza 0.03, onion_rings 0.00, donuts 0.00, 7.8ms
# image 102/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/282352.jpg: 224x224 apple_pie 0.99, onion_rings 0.00, donuts 0.00, hamburger 0.00, pizza 0.00, 8.4ms
# image 103/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2825284.jpg: 224x224 apple_pie 0.98, donuts 0.01, pizza 0.00, hamburger 0.00, onion_rings 0.00, 7.7ms
# image 104/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2839283.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, pizza 0.00, onion_rings 0.00, 8.1ms
# image 105/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2854105.jpg: 224x224 donuts 0.67, onion_rings 0.25, hamburger 0.06, apple_pie 0.03, pizza 0.00, 7.6ms
# image 106/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/285509.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, 4.2ms
# image 107/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2856273.jpg: 224x224 apple_pie 1.00, pizza 0.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, 4.1ms
# image 108/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2856319.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, 4.2ms
# image 109/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2861144.jpg: 224x224 apple_pie 0.97, hamburger 0.01, donuts 0.01, onion_rings 0.00, pizza 0.00, 4.6ms
# image 110/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2881877.jpg: 224x224 apple_pie 0.97, hamburger 0.02, donuts 0.01, onion_rings 0.00, pizza 0.00, 4.2ms
# image 111/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2902847.jpg: 224x224 apple_pie 0.99, onion_rings 0.01, donuts 0.00, hamburger 0.00, pizza 0.00, 4.3ms
# image 112/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2911777.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, 4.3ms
# image 113/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2928660.jpg: 224x224 apple_pie 1.00, pizza 0.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, 4.6ms
# image 114/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2934928.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, pizza 0.00, onion_rings 0.00, 4.4ms
# image 115/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2945592.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 4.4ms
# image 116/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2961406.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 4.4ms
# image 117/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2968495.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, pizza 0.00, 4.8ms
# image 118/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2977851.jpg: 224x224 apple_pie 0.97, donuts 0.03, hamburger 0.00, onion_rings 0.00, pizza 0.00, 4.4ms
# image 119/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2986199.jpg: 224x224 apple_pie 0.91, donuts 0.07, hamburger 0.01, pizza 0.01, onion_rings 0.00, 4.3ms
# image 120/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2989031.jpg: 224x224 donuts 0.99, apple_pie 0.01, hamburger 0.00, onion_rings 0.00, pizza 0.00, 4.4ms
# image 121/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/2994917.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, pizza 0.00, 4.3ms
# image 122/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3023096.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, pizza 0.00, onion_rings 0.00, 4.4ms
# image 123/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/305590.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 4.2ms
# image 124/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3098981.jpg: 224x224 apple_pie 1.00, hamburger 0.00, pizza 0.00, onion_rings 0.00, donuts 0.00, 4.3ms
# image 125/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3113710.jpg: 224x224 apple_pie 0.92, onion_rings 0.05, hamburger 0.03, donuts 0.00, pizza 0.00, 4.6ms
# image 126/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3134347.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 4.5ms
# image 127/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3139762.jpg: 224x224 apple_pie 0.98, hamburger 0.02, donuts 0.00, pizza 0.00, onion_rings 0.00, 4.9ms
# image 128/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3175105.jpg: 224x224 apple_pie 0.95, hamburger 0.05, onion_rings 0.00, donuts 0.00, pizza 0.00, 6.8ms
# image 129/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/317970.jpg: 224x224 apple_pie 0.95, pizza 0.05, onion_rings 0.00, hamburger 0.00, donuts 0.00, 4.4ms
# image 130/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3198655.jpg: 224x224 apple_pie 0.99, donuts 0.01, pizza 0.00, hamburger 0.00, onion_rings 0.00, 4.2ms
# image 131/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3203950.jpg: 224x224 apple_pie 1.00, donuts 0.00, pizza 0.00, hamburger 0.00, onion_rings 0.00, 4.2ms
# image 132/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3211704.jpg: 224x224 donuts 0.69, pizza 0.21, apple_pie 0.05, hamburger 0.03, onion_rings 0.02, 4.3ms
# image 133/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3252424.jpg: 224x224 apple_pie 0.94, donuts 0.06, hamburger 0.00, pizza 0.00, onion_rings 0.00, 4.6ms
# image 134/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3254296.jpg: 224x224 apple_pie 1.00, donuts 0.00, pizza 0.00, onion_rings 0.00, hamburger 0.00, 4.3ms
# image 135/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3257241.jpg: 224x224 apple_pie 0.99, hamburger 0.01, donuts 0.00, onion_rings 0.00, pizza 0.00, 4.5ms
# image 136/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3385074.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, donuts 0.00, hamburger 0.00, pizza 0.00, 4.6ms
# image 137/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/343461.jpg: 224x224 apple_pie 0.71, donuts 0.16, hamburger 0.13, onion_rings 0.00, pizza 0.00, 4.4ms
# image 138/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3463862.jpg: 224x224 apple_pie 0.82, pizza 0.16, onion_rings 0.02, donuts 0.00, hamburger 0.00, 4.4ms
# image 139/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3466310.jpg: 224x224 apple_pie 0.76, donuts 0.24, hamburger 0.00, onion_rings 0.00, pizza 0.00, 4.2ms
# image 140/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3497884.jpg: 224x224 apple_pie 0.99, hamburger 0.01, onion_rings 0.00, donuts 0.00, pizza 0.00, 4.1ms
# image 141/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3501006.jpg: 224x224 apple_pie 0.63, pizza 0.35, onion_rings 0.02, hamburger 0.00, donuts 0.00, 4.2ms
# image 142/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3503020.jpg: 224x224 donuts 0.37, apple_pie 0.29, hamburger 0.19, pizza 0.14, onion_rings 0.00, 4.3ms
# image 143/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3517723.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, donuts 0.00, 4.2ms
# image 144/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3549466.jpg: 224x224 apple_pie 0.84, onion_rings 0.12, donuts 0.04, hamburger 0.00, pizza 0.00, 5.2ms
# image 145/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3555118.jpg: 224x224 apple_pie 0.98, donuts 0.02, hamburger 0.00, onion_rings 0.00, pizza 0.00, 4.3ms
# image 146/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3596143.jpg: 224x224 apple_pie 0.89, hamburger 0.11, donuts 0.00, onion_rings 0.00, pizza 0.00, 4.5ms
# image 147/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3636185.jpg: 224x224 apple_pie 0.95, onion_rings 0.03, donuts 0.02, pizza 0.00, hamburger 0.00, 4.3ms
# image 148/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3638370.jpg: 224x224 apple_pie 0.77, onion_rings 0.19, hamburger 0.02, pizza 0.02, donuts 0.01, 4.5ms
# image 149/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3647026.jpg: 224x224 donuts 0.52, apple_pie 0.44, hamburger 0.04, pizza 0.00, onion_rings 0.00, 4.1ms
# image 150/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3659123.jpg: 224x224 apple_pie 0.75, donuts 0.22, hamburger 0.02, onion_rings 0.01, pizza 0.00, 4.8ms
# image 151/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3670966.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, pizza 0.00, onion_rings 0.00, 4.4ms
# image 152/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3687109.jpg: 224x224 apple_pie 0.99, donuts 0.01, onion_rings 0.00, hamburger 0.00, pizza 0.00, 5.3ms
# image 153/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3728481.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, 6.0ms
# image 154/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/380024.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, 7.6ms
# image 155/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3815797.jpg: 224x224 apple_pie 0.99, onion_rings 0.01, hamburger 0.00, donuts 0.00, pizza 0.00, 8.8ms
# image 156/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3825794.jpg: 224x224 apple_pie 1.00, hamburger 0.00, pizza 0.00, onion_rings 0.00, donuts 0.00, 4.4ms
# image 157/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3829004.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, 4.8ms
# image 158/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3833386.jpg: 224x224 apple_pie 1.00, hamburger 0.00, pizza 0.00, donuts 0.00, onion_rings 0.00, 4.6ms
# image 159/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3833639.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, 4.3ms
# image 160/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3848012.jpg: 224x224 apple_pie 0.96, onion_rings 0.03, hamburger 0.00, donuts 0.00, pizza 0.00, 4.1ms
# image 161/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/3890705.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 4.5ms
# image 162/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/455977.jpg: 224x224 apple_pie 1.00, hamburger 0.00, pizza 0.00, donuts 0.00, onion_rings 0.00, 4.0ms
# image 163/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/483621.jpg: 224x224 onion_rings 0.62, apple_pie 0.38, hamburger 0.00, donuts 0.00, pizza 0.00, 4.3ms
# image 164/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/523810.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, donuts 0.00, 4.1ms
# image 165/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/524697.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, 4.2ms
# image 166/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/532019.jpg: 224x224 donuts 0.60, apple_pie 0.39, hamburger 0.01, pizza 0.00, onion_rings 0.00, 4.4ms
# image 167/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/594677.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, donuts 0.00, pizza 0.00, hamburger 0.00, 4.2ms
# image 168/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/631445.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 4.2ms
# image 169/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/647043.jpg: 224x224 pizza 0.49, donuts 0.21, hamburger 0.20, apple_pie 0.09, onion_rings 0.01, 4.3ms
# image 170/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/650815.jpg: 224x224 apple_pie 1.00, donuts 0.00, pizza 0.00, onion_rings 0.00, hamburger 0.00, 4.4ms
# image 171/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/656340.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, pizza 0.00, onion_rings 0.00, 4.3ms
# image 172/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/657618.jpg: 224x224 apple_pie 0.97, hamburger 0.03, donuts 0.00, onion_rings 0.00, pizza 0.00, 4.1ms
# image 173/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/687506.jpg: 224x224 apple_pie 0.99, onion_rings 0.00, hamburger 0.00, donuts 0.00, pizza 0.00, 5.6ms
# image 174/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/688983.jpg: 224x224 apple_pie 0.76, pizza 0.18, onion_rings 0.04, donuts 0.03, hamburger 0.00, 6.2ms
# image 175/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/693210.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, pizza 0.00, donuts 0.00, hamburger 0.00, 5.4ms
# image 176/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/722783.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 4.6ms
# image 177/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/727825.jpg: 224x224 apple_pie 0.86, donuts 0.14, pizza 0.00, hamburger 0.00, onion_rings 0.00, 4.9ms
# image 178/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/742789.jpg: 224x224 apple_pie 1.00, pizza 0.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, 6.6ms
# image 179/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/755031.jpg: 224x224 donuts 0.46, hamburger 0.32, pizza 0.17, apple_pie 0.05, onion_rings 0.00, 4.3ms
# image 180/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/770439.jpg: 224x224 apple_pie 1.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, 4.4ms
# image 181/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/793078.jpg: 224x224 apple_pie 0.92, onion_rings 0.07, hamburger 0.00, donuts 0.00, pizza 0.00, 4.2ms
# image 182/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/829830.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, donuts 0.00, pizza 0.00, 4.2ms
# image 183/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/842012.jpg: 224x224 apple_pie 1.00, donuts 0.00, onion_rings 0.00, hamburger 0.00, pizza 0.00, 4.7ms
# image 184/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/854595.jpg: 224x224 apple_pie 0.99, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 4.9ms
# image 185/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/858876.jpg: 224x224 apple_pie 1.00, hamburger 0.00, pizza 0.00, onion_rings 0.00, donuts 0.00, 4.6ms
# image 186/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/873371.jpg: 224x224 apple_pie 0.56, donuts 0.40, onion_rings 0.04, hamburger 0.00, pizza 0.00, 4.2ms
# image 187/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/886793.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, hamburger 0.00, onion_rings 0.00, 5.0ms
# image 188/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/892425.jpg: 224x224 apple_pie 0.79, hamburger 0.21, pizza 0.00, onion_rings 0.00, donuts 0.00, 4.2ms
# image 189/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/913161.jpg: 224x224 apple_pie 1.00, hamburger 0.00, donuts 0.00, onion_rings 0.00, pizza 0.00, 4.8ms
# image 190/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/925525.jpg: 224x224 apple_pie 1.00, pizza 0.00, donuts 0.00, onion_rings 0.00, hamburger 0.00, 5.1ms
# image 191/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/936189.jpg: 224x224 apple_pie 1.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, pizza 0.00, 4.9ms
# image 192/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/939827.jpg: 224x224 apple_pie 0.99, donuts 0.01, hamburger 0.00, onion_rings 0.00, pizza 0.00, 6.7ms
# image 193/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/947689.jpg: 224x224 donuts 0.99, apple_pie 0.01, hamburger 0.00, pizza 0.00, onion_rings 0.00, 4.4ms
# image 194/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/954830.jpg: 224x224 apple_pie 0.97, hamburger 0.03, onion_rings 0.00, donuts 0.00, pizza 0.00, 4.6ms
# image 195/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/973088.jpg: 224x224 apple_pie 1.00, pizza 0.00, onion_rings 0.00, hamburger 0.00, donuts 0.00, 4.7ms
# image 196/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/98352.jpg: 224x224 apple_pie 1.00, hamburger 0.00, onion_rings 0.00, pizza 0.00, donuts 0.00, 6.8ms
# image 197/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/986844.jpg: 224x224 apple_pie 0.84, donuts 0.16, onion_rings 0.00, hamburger 0.00, pizza 0.00, 5.8ms
# image 198/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/99556.jpg: 224x224 apple_pie 0.88, hamburger 0.11, donuts 0.00, onion_rings 0.00, pizza 0.00, 5.4ms
# image 199/199 /content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/997950.jpg: 224x224 apple_pie 0.88, hamburger 0.08, onion_rings 0.03, donuts 0.01, pizza 0.00, 4.5ms
# Speed: 5.0ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %%
results[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: 'apple_pie', 1: 'donuts', 2: 'hamburger', 3: 'onion_rings', 4: 'pizza'}
# obb: None
# orig_img: array([[[182, 209, 235],
#         [185, 212, 238],
#         [188, 213, 239],
#         ...,
#         [ 19,  28, 101],
#         [ 17,  26, 100],
#         [ 15,  24,  98]],
#
#        [[188, 214, 238],
#         [189, 215, 239],
#         [190, 216, 240],
#         ...,
#         [ 15,  27,  99],
#         [ 16,  25,  99],
#         [ 14,  25,  99]],
#
#        [[194, 218, 240],
#         [195, 219, 241],
#         [195, 219, 241],
#         ...,
#         [ 11,  26,  95],
#         [ 15,  27,  99],
#         [ 14,  28, 100]],
#
#        ...,
#
#        [[  5,  12,  45],
#         [  4,  11,  44],
#         [  3,  10,  43],
#         ...,
#         [  1,   7,  50],
#         [  1,   7,  50],
#         [  1,   7,  50]],
#
#        [[  5,  13,  43],
#         [  5,  13,  43],
#         [  6,  14,  44],
#         ...,
#         [  1,   7,  50],
#         [  2,   8,  51],
#         [  2,   8,  51]],
#
#        [[  5,  13,  43],
#         [  7,  15,  45],
#         [  9,  17,  47],
#         ...,
#         [  3,   9,  52],
#         [  4,  10,  53],
#         [  5,  11,  54]]], dtype=uint8)
# orig_shape: (512, 512)
# path: '/content/drive/MyDrive/딥러닝/data/food_for_yolo/test/apple_pie/1014775.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs/classify/predict'
# speed: {'preprocess': 37.16524100002516, 'inference': 29.173872999990635, 'postprocess': 0.09435900005883013}
