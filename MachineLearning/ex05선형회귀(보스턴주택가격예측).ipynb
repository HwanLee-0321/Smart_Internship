# %% [markdown]
# ### 1. 문제 정의
# - 보스턴 주택 가격 데이터를 사용하여 주택 가격을 예측해 보자.
# - 회귀모델
# - LinearRegression(), SGDRegression()

# %% [markdown]
# ### 2. 데이터 수집
# - csv파일

# %%
import pandas as pd

# %%
boston_data = pd.read_csv('./boston_housing.csv', index_col=0)
boston_data.iloc[:,1:]
# Out:
#        ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0    18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3
# 1     0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8
# 2     0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8
# 3     0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7
# 4     0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7
# ..    ...    ...   ...    ...    ...   ...     ...  ...    ...      ...
# 501   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0     21.0
# 502   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0     21.0
# 503   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0     21.0
# 504   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0     21.0
# 505   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# 2    392.83   4.03  34.7
# 3    394.63   2.94  33.4
# 4    396.90   5.33  36.2
# ..      ...    ...   ...
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9
#
# [506 rows x 13 columns]

# %%
boston_data.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
# 문제데이터(X), 답 데이터(y) 분리
X = boston_data.drop('MEDV', axis=1)
X

y = boston_data['MEDV']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
X.info()
X.ndim
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 55.3 KB
# 2

# %% [markdown]
# ### 3. 데이터 전처리
# - 결측치, 이상치 확인하는 단계
# - 학습용 데이터로 전처리 생략

# %% [markdown]
# #### 3-1. 특성확장
# - 특성(문제)들끼리 곱해서 새로운 특성을 만들어보자 -->Linear 모델의 성능을 높이기 위해

# %%
# 특성 이름 확인
col = X.columns
col
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
# 특성 개수 확인
col.size
# Out:
# 13

# %%
# 특성확장을 위한 반복분
# 1. 전체 컬럼을 순서대로 꺼내오는 for
for i in range(col.size):
    # 2. 곱해지는 컬럼을 정하는 for문 한 개 필요(0~12,1~12,2~12,...12~12)
    for j in range(i, col.size):
        X[col[i] + '*' + col[j]] = X[col[i]] * X[col[j]]

X.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        ...
#        'TAX*TAX', 'TAX*PTRATIO', 'TAX*B', 'TAX*LSTAT', 'PTRATIO*PTRATIO',
#        'PTRATIO*B', 'PTRATIO*LSTAT', 'B*B', 'B*LSTAT', 'LSTAT*LSTAT'],
#       dtype='object', length=104)

# %%
X.shape
# Out:
# (506, 104)

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  ...  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0  ...
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0  ...
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0  ...
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0  ...
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0  ...
#
#    TAX*TAX  TAX*PTRATIO      TAX*B  TAX*LSTAT  PTRATIO*PTRATIO  PTRATIO*B  \
# 0  87616.0       4528.8  117482.40    1474.08           234.09   6072.570
# 1  58564.0       4307.6   96049.80    2211.88           316.84   7064.820
# 2  58564.0       4307.6   95064.86     975.26           316.84   6992.374
# 3  49284.0       4151.4   87607.86     652.68           349.69   7379.581
# 4  49284.0       4151.4   88111.80    1183.26           349.69   7422.030
#
#    PTRATIO*LSTAT          B*B    B*LSTAT  LSTAT*LSTAT
# 0         76.194  157529.6100  1976.5620      24.8004
# 1        162.692  157529.6100  3627.6660      83.5396
# 2         71.734  154315.4089  1583.1049      16.2409
# 3         54.978  155732.8369  1160.2122       8.6436
# 4         99.671  157529.6100  2115.4770      28.4089
#
# [5 rows x 104 columns]

# %% [markdown]
# #### 3-2. 데이터 스케일링
# - 주의사항: 데이터 전처리 마지막에 사용
# - 결측치가 없는 상태에서 사용해야만 함

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
# 수정 전 코드 (오류 발생)
# X_trans = minmax.transform(X)

# 수정 후 코드
X_scaled = minmax.fit_transform(X)

# %% [markdown]
# #### 4-1. 상관관계 분석
# - heatmap
# - 피어슨 상관계수: 두 컬럼의 선형도 판단
# - 컬럼 간의 상관도(선형관계)를 확인

# %%
# 문제와 답을 나누기 전 데이터
boston_data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
# 관계를 시각화하여 보기 좋게 만들어보자!
import seaborn as sns
import matplotlib.pyplot as plt

# 1) 그림판 설정
plt.figure(figsize=(12,12))

# 2) 그래프 그리기
sns.heatmap(boston_data.corr(), annot=True) 

# 3) 그림 출력!
plt.show()

# %% [markdown]
# ### 5. 모델 선택 및 하이퍼파라미터 튜닝

# %%
# 1) 수학적 공식 Linear모델
from sklearn.linear_model import LinearRegression

# 2) 경사하강법
from sklearn.linear_model import SGDRegressor

# %%
# 모델 생성
# 1)해석적 모델
linear_model = LinearRegression()
linear_model

# 2) 경사하강법
sgd_model = SGDRegressor(eta0=0.01, verbose=1)
sgd_model
# Out:
# SGDRegressor(verbose=1)

# %% [markdown]
# ### 5-1. 훈련과 평가 데이터 분리
# - 훈련7 : 평가3

# %%
# 분리하는 라이브러리
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=5)

# 확인용
print("훈련세트: ", X_train.shape, X_test.shape)
print("테스트 세트: ", y_train.shape, y_test.shape)
# Out:
# 훈련세트:  (354, 104) (152, 104)
# 테스트 세트:  (354,) (152,)

# %% [markdown]
# ### 6. 모델 학습

# %%
# 1) 해석적 모델
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 2) 경사하강법
sgd_model.fit(X_train, y_train)
# Out:
# -- Epoch 1
# Norm: 8.41, NNZs: 104, Bias: 3.214094, T: 354, Avg. loss: 44.043275
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 9.39, NNZs: 104, Bias: 3.727609, T: 708, Avg. loss: 26.420635
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 10.09, NNZs: 104, Bias: 4.111373, T: 1062, Avg. loss: 23.683609
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 10.57, NNZs: 104, Bias: 4.372584, T: 1416, Avg. loss: 21.721204
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 10.94, NNZs: 104, Bias: 4.558685, T: 1770, Avg. loss: 20.125880
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 11.45, NNZs: 104, Bias: 4.857683, T: 2124, Avg. loss: 19.071338
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 11.75, NNZs: 104, Bias: 4.976579, T: 2478, Avg. loss: 18.019399
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 12.12, NNZs: 104, Bias: 5.166788, T: 2832, Avg. loss: 17.277789
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 12.49, NNZs: 104, Bias: 5.368017, T: 3186, Avg. loss: 16.461414
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 12.79, NNZs: 104, Bias: 5.529239, T: 3540, Avg. loss: 16.072174
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 13.07, NNZs: 104, Bias: 5.677064, T: 3894, Avg. loss: 15.554988
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 13.39, NNZs: 104, Bias: 5.844560, T: 4248, Avg. loss: 15.120367
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 13.56, NNZs: 104, Bias: 5.905255, T: 4602, Avg. loss: 14.649246
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 13.84, NNZs: 104, Bias: 6.101789, T: 4956, Avg. loss: 14.389090
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 14.02, NNZs: 104, Bias: 6.186354, T: 5310, Avg. loss: 14.161809
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 14.23, NNZs: 104, Bias: 6.308907, T: 5664, Avg. loss: 13.893143
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 14.43, NNZs: 104, Bias: 6.418980, T: 6018, Avg. loss: 13.631743
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 14.62, NNZs: 104, Bias: 6.558023, T: 6372, Avg. loss: 13.316888
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 14.83, NNZs: 104, Bias: 6.689512, T: 6726, Avg. loss: 13.177690
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 14.99, NNZs: 104, Bias: 6.792904, T: 7080, Avg. loss: 13.049538
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 15.16, NNZs: 104, Bias: 6.896064, T: 7434, Avg. loss: 12.887778
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 15.24, NNZs: 104, Bias: 6.927492, T: 7788, Avg. loss: 12.742696
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 15.39, NNZs: 104, Bias: 7.031192, T: 8142, Avg. loss: 12.553435
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 15.59, NNZs: 104, Bias: 7.175362, T: 8496, Avg. loss: 12.401768
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 15.70, NNZs: 104, Bias: 7.257647, T: 8850, Avg. loss: 12.357623
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 15.83, NNZs: 104, Bias: 7.363399, T: 9204, Avg. loss: 12.165117
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 15.90, NNZs: 104, Bias: 7.387123, T: 9558, Avg. loss: 12.209568
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 16.07, NNZs: 104, Bias: 7.534379, T: 9912, Avg. loss: 11.872012
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 16.11, NNZs: 104, Bias: 7.534970, T: 10266, Avg. loss: 11.991922
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 16.27, NNZs: 104, Bias: 7.673062, T: 10620, Avg. loss: 11.769056
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 16.35, NNZs: 104, Bias: 7.713109, T: 10974, Avg. loss: 11.820221
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 16.41, NNZs: 104, Bias: 7.742901, T: 11328, Avg. loss: 11.699232
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 16.51, NNZs: 104, Bias: 7.828755, T: 11682, Avg. loss: 11.621638
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 16.61, NNZs: 104, Bias: 7.917959, T: 12036, Avg. loss: 11.575015
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 16.69, NNZs: 104, Bias: 7.979897, T: 12390, Avg. loss: 11.525557
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 16.76, NNZs: 104, Bias: 8.032932, T: 12744, Avg. loss: 11.419427
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 16.82, NNZs: 104, Bias: 8.071927, T: 13098, Avg. loss: 11.264974
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 16.90, NNZs: 104, Bias: 8.140532, T: 13452, Avg. loss: 11.312137
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 17.02, NNZs: 104, Bias: 8.263845, T: 13806, Avg. loss: 11.202705
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 17.03, NNZs: 104, Bias: 8.256171, T: 14160, Avg. loss: 11.177642
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 17.08, NNZs: 104, Bias: 8.292646, T: 14514, Avg. loss: 11.100896
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 17.21, NNZs: 104, Bias: 8.414491, T: 14868, Avg. loss: 11.137280
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 17.26, NNZs: 104, Bias: 8.449905, T: 15222, Avg. loss: 11.055652
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 17.30, NNZs: 104, Bias: 8.482632, T: 15576, Avg. loss: 11.002427
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 17.40, NNZs: 104, Bias: 8.578213, T: 15930, Avg. loss: 10.940430
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 17.43, NNZs: 104, Bias: 8.600334, T: 16284, Avg. loss: 10.929979
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 17.49, NNZs: 104, Bias: 8.645426, T: 16638, Avg. loss: 10.896410
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 17.56, NNZs: 104, Bias: 8.730826, T: 16992, Avg. loss: 10.869833
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 17.60, NNZs: 104, Bias: 8.757098, T: 17346, Avg. loss: 10.806931
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 17.68, NNZs: 104, Bias: 8.844520, T: 17700, Avg. loss: 10.748912
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 17.72, NNZs: 104, Bias: 8.862878, T: 18054, Avg. loss: 10.754236
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 17.77, NNZs: 104, Bias: 8.919222, T: 18408, Avg. loss: 10.706631
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 17.80, NNZs: 104, Bias: 8.943737, T: 18762, Avg. loss: 10.674338
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 17.87, NNZs: 104, Bias: 9.015128, T: 19116, Avg. loss: 10.646069
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 17.91, NNZs: 104, Bias: 9.057503, T: 19470, Avg. loss: 10.616044
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 17.94, NNZs: 104, Bias: 9.088466, T: 19824, Avg. loss: 10.577710
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 17.97, NNZs: 104, Bias: 9.102450, T: 20178, Avg. loss: 10.494616
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 18.04, NNZs: 104, Bias: 9.169576, T: 20532, Avg. loss: 10.529772
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 18.10, NNZs: 104, Bias: 9.254280, T: 20886, Avg. loss: 10.470600
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 18.12, NNZs: 104, Bias: 9.260283, T: 21240, Avg. loss: 10.433075
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 18.16, NNZs: 104, Bias: 9.292292, T: 21594, Avg. loss: 10.414126
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 18.19, NNZs: 104, Bias: 9.322276, T: 21948, Avg. loss: 10.395912
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 18.26, NNZs: 104, Bias: 9.402958, T: 22302, Avg. loss: 10.372034
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 18.28, NNZs: 104, Bias: 9.409985, T: 22656, Avg. loss: 10.360151
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 18.33, NNZs: 104, Bias: 9.462848, T: 23010, Avg. loss: 10.331942
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 18.37, NNZs: 104, Bias: 9.515064, T: 23364, Avg. loss: 10.304637
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 18.41, NNZs: 104, Bias: 9.547535, T: 23718, Avg. loss: 10.293391
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 18.43, NNZs: 104, Bias: 9.561418, T: 24072, Avg. loss: 10.242409
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 18.49, NNZs: 104, Bias: 9.633430, T: 24426, Avg. loss: 10.194541
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 18.54, NNZs: 104, Bias: 9.688630, T: 24780, Avg. loss: 10.145038
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 18.55, NNZs: 104, Bias: 9.683958, T: 25134, Avg. loss: 10.205300
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 18.59, NNZs: 104, Bias: 9.735774, T: 25488, Avg. loss: 10.114909
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 18.61, NNZs: 104, Bias: 9.733676, T: 25842, Avg. loss: 10.111794
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 18.68, NNZs: 104, Bias: 9.833033, T: 26196, Avg. loss: 10.045518
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 18.68, NNZs: 104, Bias: 9.818871, T: 26550, Avg. loss: 10.126668
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 18.73, NNZs: 104, Bias: 9.875483, T: 26904, Avg. loss: 10.064490
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 18.73, NNZs: 104, Bias: 9.857402, T: 27258, Avg. loss: 9.998825
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 18.77, NNZs: 104, Bias: 9.901140, T: 27612, Avg. loss: 10.045502
# Total training time: 0.00 seconds.
# -- Epoch 79
# Norm: 18.81, NNZs: 104, Bias: 9.942253, T: 27966, Avg. loss: 10.032413
# Total training time: 0.00 seconds.
# -- Epoch 80
# Norm: 18.85, NNZs: 104, Bias: 9.979373, T: 28320, Avg. loss: 10.009550
# Total training time: 0.00 seconds.
# -- Epoch 81
# Norm: 18.87, NNZs: 104, Bias: 9.999736, T: 28674, Avg. loss: 9.953071
# Total training time: 0.00 seconds.
# -- Epoch 82
# Norm: 18.91, NNZs: 104, Bias: 10.034221, T: 29028, Avg. loss: 9.969902
# Total training time: 0.00 seconds.
# -- Epoch 83
# Norm: 18.96, NNZs: 104, Bias: 10.113968, T: 29382, Avg. loss: 9.900915
# Total training time: 0.00 seconds.
# -- Epoch 84
# Norm: 18.98, NNZs: 104, Bias: 10.125627, T: 29736, Avg. loss: 9.892446
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 19.00, NNZs: 104, Bias: 10.130659, T: 30090, Avg. loss: 9.915241
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 19.02, NNZs: 104, Bias: 10.153244, T: 30444, Avg. loss: 9.884951
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 19.06, NNZs: 104, Bias: 10.199732, T: 30798, Avg. loss: 9.888542
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 19.10, NNZs: 104, Bias: 10.231738, T: 31152, Avg. loss: 9.858813
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 19.13, NNZs: 104, Bias: 10.269748, T: 31506, Avg. loss: 9.846510
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 19.16, NNZs: 104, Bias: 10.301404, T: 31860, Avg. loss: 9.827777
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 19.17, NNZs: 104, Bias: 10.308873, T: 32214, Avg. loss: 9.798667
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 19.20, NNZs: 104, Bias: 10.326964, T: 32568, Avg. loss: 9.782669
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 19.25, NNZs: 104, Bias: 10.386986, T: 32922, Avg. loss: 9.727637
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 19.28, NNZs: 104, Bias: 10.413247, T: 33276, Avg. loss: 9.778354
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 19.29, NNZs: 104, Bias: 10.408719, T: 33630, Avg. loss: 9.733413
# Total training time: 0.00 seconds.
# -- Epoch 96
# Norm: 19.32, NNZs: 104, Bias: 10.452170, T: 33984, Avg. loss: 9.730736
# Total training time: 0.00 seconds.
# -- Epoch 97
# Norm: 19.35, NNZs: 104, Bias: 10.480153, T: 34338, Avg. loss: 9.723627
# Total training time: 0.00 seconds.
# -- Epoch 98
# Norm: 19.39, NNZs: 104, Bias: 10.527259, T: 34692, Avg. loss: 9.636026
# Total training time: 0.00 seconds.
# -- Epoch 99
# Norm: 19.41, NNZs: 104, Bias: 10.537561, T: 35046, Avg. loss: 9.705326
# Total training time: 0.00 seconds.
# -- Epoch 100
# Norm: 19.45, NNZs: 104, Bias: 10.587773, T: 35400, Avg. loss: 9.609079
# Total training time: 0.00 seconds.
# -- Epoch 101
# Norm: 19.46, NNZs: 104, Bias: 10.582531, T: 35754, Avg. loss: 9.629446
# Total training time: 0.00 seconds.
# -- Epoch 102
# Norm: 19.49, NNZs: 104, Bias: 10.617352, T: 36108, Avg. loss: 9.648340
# Total training time: 0.00 seconds.
# -- Epoch 103
# Norm: 19.51, NNZs: 104, Bias: 10.631375, T: 36462, Avg. loss: 9.656645
# Total training time: 0.00 seconds.
# -- Epoch 104
# Norm: 19.54, NNZs: 104, Bias: 10.656941, T: 36816, Avg. loss: 9.600435
# Total training time: 0.00 seconds.
# -- Epoch 105
# Norm: 19.56, NNZs: 104, Bias: 10.681939, T: 37170, Avg. loss: 9.617399
# Total training time: 0.00 seconds.
# -- Epoch 106
# Norm: 19.57, NNZs: 104, Bias: 10.678115, T: 37524, Avg. loss: 9.555861
# Total training time: 0.00 seconds.
# -- Epoch 107
# Norm: 19.62, NNZs: 104, Bias: 10.730422, T: 37878, Avg. loss: 9.587699
# Total training time: 0.00 seconds.
# -- Epoch 108
# Norm: 19.64, NNZs: 104, Bias: 10.762940, T: 38232, Avg. loss: 9.534960
# Total training time: 0.00 seconds.
# -- Epoch 109
# Norm: 19.65, NNZs: 104, Bias: 10.765007, T: 38586, Avg. loss: 9.535066
# Total training time: 0.01 seconds.
# -- Epoch 110
# Norm: 19.68, NNZs: 104, Bias: 10.791467, T: 38940, Avg. loss: 9.561365
# Total training time: 0.01 seconds.
# -- Epoch 111
# Norm: 19.69, NNZs: 104, Bias: 10.796769, T: 39294, Avg. loss: 9.459077
# Total training time: 0.01 seconds.
# -- Epoch 112
# Norm: 19.71, NNZs: 104, Bias: 10.800397, T: 39648, Avg. loss: 9.472566
# Total training time: 0.01 seconds.
# -- Epoch 113
# Norm: 19.76, NNZs: 104, Bias: 10.879662, T: 40002, Avg. loss: 9.520296
# Total training time: 0.01 seconds.
# -- Epoch 114
# Norm: 19.78, NNZs: 104, Bias: 10.896386, T: 40356, Avg. loss: 9.487484
# Total training time: 0.01 seconds.
# -- Epoch 115
# Norm: 19.78, NNZs: 104, Bias: 10.875670, T: 40710, Avg. loss: 9.428194
# Total training time: 0.01 seconds.
# -- Epoch 116
# Norm: 19.81, NNZs: 104, Bias: 10.895217, T: 41064, Avg. loss: 9.412196
# Total training time: 0.01 seconds.
# -- Epoch 117
# Norm: 19.84, NNZs: 104, Bias: 10.938227, T: 41418, Avg. loss: 9.486053
# Total training time: 0.01 seconds.
# -- Epoch 118
# Norm: 19.87, NNZs: 104, Bias: 10.964452, T: 41772, Avg. loss: 9.460552
# Total training time: 0.01 seconds.
# -- Epoch 119
# Norm: 19.89, NNZs: 104, Bias: 10.994370, T: 42126, Avg. loss: 9.447725
# Total training time: 0.01 seconds.
# -- Epoch 120
# Norm: 19.91, NNZs: 104, Bias: 11.009376, T: 42480, Avg. loss: 9.439271
# Total training time: 0.01 seconds.
# -- Epoch 121
# Norm: 19.93, NNZs: 104, Bias: 11.015321, T: 42834, Avg. loss: 9.411262
# Total training time: 0.01 seconds.
# Convergence after 121 epochs took 0.01 seconds
# SGDRegressor(verbose=1)

# %% [markdown]
# ### 7. 예측 및 평가

# %%
# 1) 해석적 모델
linear_model.score(X_train, y_train)  # 93점
# Out:
# 0.9332471683804471

# %%
# 테스트용 데이터 평가
linear_model.score(X_test, y_test)  # 80점

# 과대적합
# Out:
# 0.80935367589194

# %%
# 2) 경사하강법
# 훈련용 데이터 평가
sgd_model.score(X_train, y_train)

# 과소적합
# Out:
# 0.7663877420717355

# %%
# 테스트용 데이터 평가
sgd_model.score(X_test, y_test)
# Out:
# 0.6862969036235432

# %% [markdown]
# ### 8. 규제를 적용시킨 모델
# - LinearRegression 모델이 가지고 있는 단점 <br>
#     ㄴ 모델이 잘못되었을 경우 수정이 불가능 -> 과대적합 상태를 제어 불가 <br>
#     ㄴ 규제를 가해서 단점을 해소
# - LinearRegression + L1 규제 ==> 특성 중 중요한 특성'만' 이용
# - LinearRegression + L2 규제 ==> 중요도가 높은 특성은 더 중요하게, 중요도가 낮은 것들을<br>
#                                  덜 중요하게 반영(0이 되지는 않음)
# - 규제? ==> 선형모델에서 가중치에 영향을 주겠다 <br>
#         ==> 가중치의 비중을 줄이겠다.

# %% [markdown]
# ### 8-1. Ridge(L2)활용하기

# %%
# 라이브러리 불러오기
from sklearn.linear_model import Ridge, Lasso

# %%
# 규제를 크게, 적게 했을 때 차이를 볼려고 함.
# 하이퍼파라미터(alpha) 튜닝하는 함수 정의

# L2(Ridge)
def ridge_alpha(alpha):
    # ridge모델 생성(객체 생성)
    ridge = Ridge(alpha=alpha)
    # 학습
    ridge.fit(X_train, y_train)
    # 평가
    # 훈련용평가
    print(alpha, "학습률 train_score: ",ridge.score(X_train, y_train))
    # 테스트용평가
    print(alpha, "학습률 test_score", ridge.score(X_test, y_test))

# %%
# 규제가 심해지면 모델이 복잡해 지는 것을 방지!
# 과대적합일 때 사용해서 과대적합을 방지
# ==> 과소적합이 생길 이슈가 있음

# 규제가 적어지면 모델이 복잡해 지는 것을 방지!
# 과소적합일 때 사용해서 과소적합을 방지
# ==> 과대적합이 생길 이슈가 있음

ridge_alpha(0.01)
ridge_alpha(0.1)
ridge_alpha(1)
ridge_alpha(10)
ridge_alpha(100)
# Out:
# 0.01 학습률 train_score:  0.9221166711911322
# 0.01 학습률 test_score 0.8740830034872126
# 0.1 학습률 train_score:  0.8956144374795688
# 0.1 학습률 test_score 0.8707619590126977
# 1 학습률 train_score:  0.8360143538944645
# 1 학습률 test_score 0.7859478376780065
# 10 학습률 train_score:  0.7610192708361805
# 10 학습률 test_score 0.6881701591663667
# 100 학습률 train_score:  0.5867470593740552
# 100 학습률 test_score 0.4908590961177438

# %%
import numpy as np

# L1(Lasso)
def lasso_alpha(alpha):
    # ridge모델 생성(객체 생성)
    lasso = Lasso(alpha=alpha)
    # 학습
    lasso.fit(X_train, y_train)
    # 평가
    # 훈련용평가
    print(alpha, "학습률 train_score: ",lasso.score(X_train, y_train))
    # 테스트용평가
    print(alpha, "학습률 test_score", lasso.score(X_test, y_test))

    # 사용한 특성의 개수
    print('사용한 특성의 개수: ', np.sum(lasso.coef_ != 0))

# %%
# 규제를 늘릴수록 점수가 안 나옴 ==> 과소적합
# 규제를 줄일수록 점수가 잘 나옴 ==> 과대적합

lasso_alpha(0.001)
lasso_alpha(0.01)
lasso_alpha(0.1)
lasso_alpha(1)
lasso_alpha(10)
lasso_alpha(100)
lasso_alpha(1000)
# Out:
# 0.001 학습률 train_score:  0.9090011997244047
# 0.001 학습률 test_score 0.8600261087920087
# 사용한 특성의 개수:  78
# 0.01 학습률 train_score:  0.8604801273989778
# 0.01 학습률 test_score 0.8154143659124607
# 사용한 특성의 개수:  29
# 0.1 학습률 train_score:  0.759085798220589
# 0.1 학습률 test_score 0.6811210661785797
# 사용한 특성의 개수:  8
# 1 학습률 train_score:  0.2572648124335003
# 1 학습률 test_score 0.19118225902593067
# 사용한 특성의 개수:  3
# 10 학습률 train_score:  0.0
# 10 학습률 test_score -6.386072533048903e-05
# 사용한 특성의 개수:  0
# 100 학습률 train_score:  0.0
# 100 학습률 test_score -6.386072533048903e-05
# 사용한 특성의 개수:  0
# 1000 학습률 train_score:  0.0
# 1000 학습률 test_score -6.386072533048903e-05
# 사용한 특성의 개수:  0
# c:\Users\USER\anaconda3\envs\dev\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.310e+03, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\envs\dev\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.637e+02, tolerance: 2.826e+00
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# ### Ridge랑 Lasso의 차이
# - Ridge는 중요도를 조정한다 <br>
#     ㄴ 중요한 건 더 중요하고, 안 중요한건 덜 중요하게
# - Lasso는 안중요한건 삭제
